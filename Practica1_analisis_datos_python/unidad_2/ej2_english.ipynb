# %% [markdown]
# <div id="navegacion" prev="../Ejercicios_Tema_2/ej1.html"
#                      next=""></div>
#
# <div class="section-title">Sección 2.9</div>

# %% [markdown]
# #  Exercises

# %% [markdown]
# ##  Exercise 1

# %% [markdown]
# Given the list L = [ 'a', 'b', 'c', 4, 5, 6, 7, 8, 9 ], write the Python expressions that will produce the following outputs:
#
# 1. First element of the list.
# 2. Last element of the list (without knowing the list length).
# 3. The sublist with the two last elements.
# 4. The sublist with the elements that are in the even positions.
# 4. The sublist with the elements that are in the odd positions.

# %%
# Sol 1: 'a'

# %%
# Sol 2: 9

# %%
# Sol 3: [8,9]

# %%
# Sol 4:  [ 'a',  'c', 5,  7,  9 ]

# %%
# Sol 5:  [ 'b', 4, 6, 8 ]

# %% [markdown]
# ## Excercise 2

# %% [markdown]
# Given a list of prices, we want to compute the % of VAT (Value Added Tax, for instance 21%) for each price. Write a function named `compute_vat` that receives as input the list of numerical values and the VAT % to apply (VAT is greater than 0 and less than 100). The function will return a new list of numerical values where each number is the result of applying the VAT % for every value of the original list.
#
# You can write a result list using a *list comprehension*.
#
# __Remark:__
#
# * `compute_vat([100], 21)`  returns as result the list `[21.0]`
# * `compute_vat([100, 1000, 200, 150], 21)` returns as result the list `[21.0, 210.0, 42.0, 31.5]`
# * `compute_vat([100, 1000, 200, 150], 4)` returns as result the list `[4.0, 40.0, 8.0, 6.0]`

# %%
# Sol:

# %% [markdown]
# ## Excersice 3
#
# The first 5 elements of the succession are:
#
# ```
# [3, 8, 13, 18, 23]
# ```
#
# Define a lambda function `succession` that will recive a positive integer `n` as input and will generate a list with the first `n` elements of the succession. Solve the problem using the equation $a_n = 3 + 5 * (n-1)$.
#
# You can write a result list using a *list comprehension*.
#
# __Remark:__
#
# * Write the first n elements starting at 1 and using the __range__ function.

# %%
# Sol:

# %% [markdown]
# ## Excercise 4
#
# Given a dictionary with the names of the most populated cities in Italy __cities__:
#
# d =  { 1: 'Roma', 2: 'Milán', 3:'Nápoles', 4:'Turín', 5:'Palermo' ,6: 'Génova',
#       7:'Bolonia', 8:'Florencia', 9:'Bari', 10:'Catania'}
#
# and the list __pob__ that contains the information about the population for each city:
#
# pob =  [2718768, 1299633, 973132, 908263, 663173, 610887, 372256, 364710, 322511, 298957]
#
# Create a new dictionary where each element has the format
#
# __i: [city,population]__
#
# You can create a dictionary using a *list comprehension*.

# %%
pob = [2718768, 1299633, 973132, 908263, 663173, 610887, 372256, 364710, 
       322511, 298957]
d = { 1: 'Roma', 2: 'Milán', 3:'Nápoles', 4:'Turín', 5:'Palermo' ,
     6: 'Génova',   \
      7:'Bolonia', 8:'Florencia', 9:'Bari', 10:'Catania'}
# Sol

# %% [markdown]
# -------------------
