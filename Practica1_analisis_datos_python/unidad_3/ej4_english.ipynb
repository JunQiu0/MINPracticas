# %% [markdown]
# <div id="navegacion" prev="../Ejercicios_Tema_6/uso_numpy.html" next=""></div>
#
# <div class="section-title">Section 3.7</div>

# %% [markdown]
# # Exercises

# %% [markdown]
# The links that you will find in this page only work if you read the file in HTML format, not for the Notebook format.

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# The file [rotterdam_rainfall.txt](./datos/rotterdam_rainfall.txt) collects the daily rainfall information of a weather station in Rotterdam for 2012.
#
# * The first column corresponds to the date.
# * The second column corresponds the amount of rain represented in 0.1 mm (-1 if it is less than 0.05 mm).
# * The field separator is the `, ` character.
#
# __a)__ Create a `numpy` array with the data in the file [rotterdam_rainfall.txt](./datos/rotterdam_rainfall.txt). The array should be named `precipitaciones`.
#
#    * Download the files in your home directory.
#    * Load each file using the `loadtxt` function. Use the parameter `delimiter` with value `,`. Use the parameter `dtype` for specifying that the values are of type `int`.

# %%
# Sol
import numpy as np

# %% [markdown]
# __b)__ Find out the number of days the amount of rainfall is greater than 0.05 mm (value greater than -1).
#
# * First, create filter for the amount of rainfall (column 1) greater than -1.
# * Next, apply the filter to the array `precipitaciones`. Save the result in a new array named `precip_positivas`.
# * You can use the `len` function to know the size of the `precip_positivas` array.

# %%
# Sol: 324 days

# %% [markdown]
# __c)__ Compute the average value for the rainfalls. Do not take into account the negative values (-1), then use the `precip_positivas` array for computing the average.
#
#    * You can use the `mean` function.

# %%
# Sol: 30.700617283950617

# %% [markdown]
# __d)__ Compute the day with the highest amount of rainfall, and the amount of rainfall.
#
#    * Use the `argmax` and `max` functions.

# %%
# Sol: Maximum rainfall: 224. 
#      Day with maximum rainfall : 20121222

# %% [markdown]
# __e)__ Compute the amount of rainfall in mm. To do that, multiply the amount of rainfall by 10.

# %%
# Sol: Ther first values are:

#    array([[20120101,     2070],
#           [20120102,      -10],
#           [20120103,     1440],
#           [20120104,      360],
#            ...
#            ...

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# Two kids are collecting a collection of cards. Each card has assigned a number between 1 and 200.
#
# * John's cards are in the file [juan.txt](./datos/col_juan.txt). The first column corresponds to the card id (number between 1 and 200) and the second column corresponds to the number of cards with that value that John has.
#
# * Peter's cards are in the file [pedro.txt](./datos/col_pedro.txt). The first column corresponds to the card id (number between 1 and 200) and the second column corresponds to the number of cards with that value that Peter has.
#
# __a)__ Create a `numpy` array with the values of each collection. The name of the arrays will be `juan` and `pedro`.
#
#    * Download the files in your home directory.
#    * Load each file using the `loadtxt` function. Use the parameter `delimiter` with value `,`. Use the parameter `dtype` for specifying that the values are of type `int`.

# %%
# Sol:

# %% [markdown]
# __b)__ Compute the number of different cards that each kid has.

# %%
# Sol: 
# john has 68 cards
# peter has 124 cards

# %% [markdown]
# __c)__ Compute the total number of cards that each kid has (counting the repeated cards).

# %%
# SOl: 
# peter has 1326 cards 
# john has 619 cards

# %% [markdown]
# __d)__ Compute the number of cards that appear in both collections. You can use the `np.intersect1d` function.

# %%
# Sol
# There are 44 cards that appear in both collections

# %% [markdown]
# __e)__ Combining the cards of both kids, do they have the complete collection?. You can use the `np.union1d` function.

# %%
# Sol: 
# They do not have the complete collection. Using both collections, they only have 148 different cards and the complete collection has 200 cards

# %% [markdown]
# __f)__ Which card numbers are missing in order to complete the collection?
#
# * You can generate an array with all the card ids for the complete collection using the `arange` function.
# * Next, use the function `np.in1d`

# %%
# Sol:
# The missing cards are:
#      [  1,   3,  12,  16,  17,  21,  30,  34,  38,  45,  46,  48,  52,
#        55,  66,  69,  72,  75,  76,  81,  82,  91,  92,  96, 100, 106,
#       107, 113, 114, 119, 122, 124, 125, 129, 138, 139, 140, 146, 151,
#       154, 155, 173, 176, 180, 181, 184, 185, 186, 190, 194, 199, 200]

# %% [markdown]
# ---------------------
